# %%
from subprocess import Popen, PIPE

# %%
# !ls ../answer/
# Out:
# a.out  main.cpp  out.txt  perf.data  perf.data.old

# %%
for i in range(20):
    i = f"{i:04d}"
    print(i)
    # !time ../tools/target/release/tester ../answer/a.out < ../tools/in/{i}.txt > out.txt
    print()
# Out:
# 0000
# [simplex] iteration = 694
# [simplex] iteration = 643
# [simplex] iteration = 691
# [simplex] iteration = 686
# [simplex] iteration = 709
# [simplex] iteration = 643
# [simplex] iteration = 753
# [simplex] iteration = 737
# [simplex] iteration = 719
# [simplex] iteration = 723
# [simplex] iteration = 730
# [simplex] iteration = 740
# [simplex] iteration = 722
# [simplex] iteration = 716
# [simplex] iteration = 834
# [simplex] iteration = 736
# [simplex] iteration = 692
# [simplex] iteration = 624
# [simplex] iteration = 756
# [simplex] iteration = 580
# [simplex] iteration = 649
# [simplex] iteration = 508
# [simplex] iteration = 360
# [simplex] iteration = 44
# Score = 2190
#
# real	0m2.387s
# user	0m2.386s
# sys	0m0.159s
#
# 0001
# [simplex] iteration = 611
# [simplex] iteration = 677
# [simplex] iteration = 678
# [simplex] iteration = 776
# [simplex] iteration = 723
# [simplex] iteration = 697
# [simplex] iteration = 549
# [simplex] iteration = 467
# ...
